# %%
x = 10
y = 25.5

# %%
type(x)
# Out:
# int

# %%
type(y)
# Out:
# float

# %%
z = x*y

# %%
z
# Out:
# 255.0

# %%
r = 25//2

# %%
r
# Out:
# 12

# %%
res, rem = divmod(25,2)

# %%
res, rem
# Out:
# (12, 1)

# %%
z = (y-5)*x

# %%
z
# Out:
# 205.0
